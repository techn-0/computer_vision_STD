# %% [markdown]
# <a href="https://colab.research.google.com/github/techn-0/computer_vision_STD/blob/main/4_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage
import numpy as np
import cv2 as cv
import time
from google.colab.patches import cv2_imshow
from skimage import graph

coffee = skimage.data.coffee()

start = time.time()
slic = skimage.segmentation.slic(coffee, compactness = 20, n_segments = 600, start_label = 1)

# g = skimage.future.graph.rag_mean_color(coffee, slic, mode = 'similarity')
# ncut = skimage.future.graph.cut_normalized(slic, g)

g = graph.rag_mean_color(coffee, slic, mode='similarity')
ncut = graph.cut_normalized(slic, g)

print(coffee.shape, 'Coffe영상을 분할하는데', time.time() - start, '초 소요')

marking = skimage.segmentation.mark_boundaries(coffee, ncut)
ncut_coffee = np.uint8(marking * 255.0)

cv2_imshow(cv.cvtColor(ncut_coffee, cv.COLOR_RGB2BGR))
# Out:
# (400, 600, 3) Coffe영상을 분할하는데 3.431293487548828 초 소요
# <PIL.Image.Image image mode=RGB size=600x400>
