# %% [markdown]
# <a href="https://colab.research.google.com/github/techn-0/computer_vision_STD/blob/main/3_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('/content/엄마 제가 크래프톤에 올랐어요.jpg')

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray'), plt.xticks([]), plt.yticks([]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7dad4f6bc790>, ([], []), ([], []), None)

# %%
h = cv.calcHist([gray], [0], None, [256], [0, 256])
plt.plot(h,color='pink', linewidth=1), plt.show()
# Out:
# ([<matplotlib.lines.Line2D at 0x7dad4ec26d90>], None)

# %%
equal = cv.equalizeHist(gray)
plt.imshow(equal, cmap='gray'), plt.xticks([]), plt.yticks([]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7dad4ee94650>, ([], []), ([], []), None)

# %%
h = cv.calcHist([equal], [0], None, [256], [0, 256])
plt.plot(h,color='b', linewidth=1), plt.show()
# Out:
# ([<matplotlib.lines.Line2D at 0x7dad4f19bfd0>], None)
