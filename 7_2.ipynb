# %% [markdown]
# <a href="https://colab.research.google.com/github/techn-0/computer_vision_STD/blob/main/7_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

mlp = Sequential()
mlp.add(Dense(units=512, activation='sigmoid', input_shape=(784,))) # 은닉층 활성함수 시그노이드로 변경
mlp.add(Dense(units=10, activation='softmax'))

mlp.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.1), metrics=['accuracy']) # learning_rate 값 수정: 높은 발산에서의 결과를 보기위해 수정
mlp.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_test, y_test), verbose = 2)

res = mlp.evaluate(x_test, y_test, verbose=0)
print('정확률=', res[1] * 100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 469/469 - 11s - 24ms/step - accuracy: 0.8338 - loss: 0.8917 - val_accuracy: 0.8824 - val_loss: 0.4137
# Epoch 2/50
# 469/469 - 5s - 12ms/step - accuracy: 0.8857 - loss: 0.4449 - val_accuracy: 0.9036 - val_loss: 0.3815
# Epoch 3/50
# 469/469 - 5s - 11ms/step - accuracy: 0.8836 - loss: 0.4766 - val_accuracy: 0.8835 - val_loss: 0.5478
# Epoch 4/50
# 469/469 - 5s - 10ms/step - accuracy: 0.8960 - loss: 0.4587 - val_accuracy: 0.9045 - val_loss: 0.3965
# Epoch 5/50
# 469/469 - 6s - 14ms/step - accuracy: 0.8975 - loss: 0.4792 - val_accuracy: 0.8949 - val_loss: 0.4832
# Epoch 6/50
# 469/469 - 9s - 20ms/step - accuracy: 0.8988 - loss: 0.5068 - val_accuracy: 0.8834 - val_loss: 0.6081
# Epoch 7/50
# 469/469 - 5s - 12ms/step - accuracy: 0.9020 - loss: 0.4837 - val_accuracy: 0.9006 - val_loss: 0.5920
# Epoch 8/50
# 469/469 - 5s - 11ms/step - accuracy: 0.9105 - loss: 0.4639 - val_accuracy: 0.9204 - val_loss: 0.4060
# Epoch 9/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9087 - loss: 0.4691 - val_accuracy: 0.9170 - val_loss: 0.5067
# Epoch 10/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9121 - loss: 0.4632 - val_accuracy: 0.9252 - val_loss: 0.4184
# Epoch 11/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9153 - loss: 0.4588 - val_accuracy: 0.9170 - val_loss: 0.4735
# Epoch 12/50
# 469/469 - 9s - 20ms/step - accuracy: 0.9121 - loss: 0.4955 - val_accuracy: 0.9070 - val_loss: 0.5169
# Epoch 13/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9127 - loss: 0.4838 - val_accuracy: 0.9030 - val_loss: 0.5817
# Epoch 14/50
# 469/469 - 5s - 11ms/step - accuracy: 0.9207 - loss: 0.4512 - val_accuracy: 0.9113 - val_loss: 0.5795
# Epoch 15/50
# 469/469 - 7s - 14ms/step - accuracy: 0.9213 - loss: 0.4426 - val_accuracy: 0.8918 - val_loss: 0.6620
# Epoch 16/50
# 469/469 - 8s - 18ms/step - accuracy: 0.9217 - loss: 0.4505 - val_accuracy: 0.9251 - val_loss: 0.4440
# Epoch 17/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9158 - loss: 0.5253 - val_accuracy: 0.9239 - val_loss: 0.5158
# Epoch 18/50
# 469/469 - 10s - 21ms/step - accuracy: 0.9232 - loss: 0.4825 - val_accuracy: 0.9130 - val_loss: 0.4922
# Epoch 19/50
# 469/469 - 4s - 9ms/step - accuracy: 0.
50
# 469/469 - 5s - 10ms/step - accuracy: 0.9356 - loss: 0.4579 - val_accuracy: 0.9290 - val_loss: 0.5319
# Epoch 45/50
# 469/469 - 7s - 14ms/step - accuracy: 0.9374 - loss: 0.4266 - val_accuracy: 0.9356 - val_loss: 0.5570
# Epoch 46/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9366 - loss: 0.4537 - val_accuracy: 0.9279 - val_loss: 0.6273
# Epoch 47/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9388 - loss: 0.4356 - val_accuracy: 0.9399 - val_loss: 0.5224
# Epoch 48/50
# 469/469 - 6s - 14ms/step - accuracy: 0.9372 - loss: 0.4536 - val_accuracy: 0.9447 - val_loss: 0.4593
# Epoch 49/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9357 - loss: 0.4945 - val_accuracy: 0.9276 - val_loss: 0.6217
# Epoch 50/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9388 - loss: 0.4496 - val_accuracy: 0.9329 - val_loss: 0.5563
# 정확률= 93.29000115394592

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD, Adam

(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

#SGD
mlp_sgd = Sequential()
mlp_sgd.add(Dense(units=512, activation='sigmoid', input_shape=(784,))) # 은닉층 활성함수 시그노이드로 변경
mlp_sgd.add(Dense(units=10, activation='softmax'))

mlp_sgd.compile(loss='categorical_crossentropy', optimizer=SGD(learning_rate=0.1), metrics=['accuracy']) # learning_rate 값 수정: 높은 발산에서의 결과를 보기위해 수정
hist_sgd = mlp_sgd.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_test, y_test), verbose = 2) # 배치사이즈를 줄여 더 자주 업데이트 하게 함

res = mlp_sgd.evaluate(x_test, y_test, verbose=2)
print('SGD 정확률=', mlp_sgd.evaluate(x_test, y_test, verbose = 0) [1] * 100)
# Adam
mlp_adam = Sequential()
mlp_adam.add(Dense(units=512, activation='sigmoid', input_shape=(784,))) # 은닉층 활성함수 시그노이드로 변경
mlp_adam.add(Dense(units=10, activation='softmax'))

mlp_adam.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.1), metrics=['accuracy']) # learning_rate 값 수정: 높은 발산에서의 결과를 보기위해 수정
hist_adam = mlp_adam.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_test, y_test), verbose = 2) # 배치사이즈를 줄여 더 자주 업데이트 하게 함

res = mlp_adam.evaluate(x_test, y_test, verbose=2)
print('Adam 정확률=', mlp_adam.evaluate(x_test, y_test, verbose = 0) [1] * 100)

# 정확률 그래프
import matplotlib.pyplot as plt

plt.plot(hist_sgd.history['accuracy'], 'r--')
plt.plot(hist_sgd.history['val_accuracy'],'r')
plt.plot(hist_adam.history['accuracy'], 'b--')
plt.plot(hist_adam.history['val_accuracy'],'b')

plt.title('Comparison of SGD and Adam optimizers')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim((0.6, 1.0)) # 축범위 조절
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train_sgd', 'val_sgd', 'train_adam', 'val_adam'])
plt.grid()
plt.show()

# Loss그래프

plt.figure(figsize=(8,5)) # 그래프 가로, 세로 크기 조절

# 훈련 손실 (SGD)
plt.plot(hist_sgd.history['loss'], linestyle='--', label='train_sgd_loss')
# 검증 손실 (SGD)
plt.plot(hist_sgd.history['val_loss'],       label='val_sgd_loss')

# 훈련 손실 (Adam)
plt.plot(hist_adam.history['loss'], linestyle='--', label='train_adam_loss')
# 검증 손실 (Adam)
plt.plot(hist_adam.history['val_loss'],       label='val_adam_loss')

plt.title('Optimizer별 손실(Loss) 곡선 비교')      # 그래프 제목
plt.xlabel('Epochs')                            # x축 레이블
plt.ylabel('Loss')                              # y축 레이블
plt.legend()                                    # 범례 표시
plt.grid()
plt.show()
# Out:
# Epoch 1/50
# 469/469 - 5s - 11ms/step - accuracy: 0.7739 - loss: 0.8842 - val_accuracy: 0.8667 - val_loss: 0.4815
# Epoch 2/50
# 469/469 - 4s - 8ms/step - accuracy: 0.8844 - loss: 0.4210 - val_accuracy: 0.8980 - val_loss: 0.3615
# Epoch 3/50
# 469/469 - 5s - 11ms/step - accuracy: 0.8970 - loss: 0.3626 - val_accuracy: 0.9048 - val_loss: 0.3303
# Epoch 4/50
# 469/469 - 6s - 12ms/step - accuracy: 0.9034 - loss: 0.3363 - val_accuracy: 0.9116 - val_loss: 0.3108
# Epoch 5/50
# 469/469 - 4s - 8ms/step - accuracy: 0.9076 - loss: 0.3206 - val_accuracy: 0.9143 - val_loss: 0.2993
# Epoch 6/50
# 469/469 - 7s - 14ms/step - accuracy: 0.9110 - loss: 0.3100 - val_accuracy: 0.9114 - val_loss: 0.3036
# Epoch 7/50
# 469/469 - 4s - 8ms/step - accuracy: 0.9129 - loss: 0.3017 - val_accuracy: 0.9180 - val_loss: 0.2899
# Epoch 8/50
# 469/469 - 4s - 8ms/step - accuracy: 0.9153 - loss: 0.2942 - val_accuracy: 0.9178 - val_loss: 0.2852
# Epoch 9/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9170 - loss: 0.2888 - val_accuracy: 0.9198 - val_loss: 0.2802
# Epoch 10/50
# 469/469 - 4s - 8ms/step - accuracy: 0.9183 - loss: 0.2829 - val_accuracy: 0.9225 - val_loss: 0.2728
# Epoch 11/50
# 469/469 - 4s - 8ms/step - accuracy: 0.9208 - loss: 0.2777 - val_accuracy: 0.9215 - val_loss: 0.2713
# Epoch 12/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9216 - loss: 0.2729 - val_accuracy: 0.9236 - val_loss: 0.2630
# Epoch 13/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9228 - loss: 0.2684 - val_accuracy: 0.9248 - val_loss: 0.2621
# Epoch 14/50
# 469/469 - 4s - 8ms/step - accuracy: 0.9251 - loss: 0.2629 - val_accuracy: 0.9247 - val_loss: 0.2626
# Epoch 15/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9263 - loss: 0.2586 - val_accuracy: 0.9268 - val_loss: 0.2571
# Epoch 16/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9281 - loss: 0.2533 - val_accuracy: 0.9268 - val_loss: 0.2492
# Epoch 17/50
# 469/469 - 4s - 8ms/step - accuracy: 0.9299 - loss: 0.2487 - val_accuracy: 0.9293 - val_loss: 0.2466
# Epoch 18/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9305 - loss: 0.2435 - val_accuracy: 0.9319 - val_loss: 0.2420
# Epoch 19/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9326 - loss: 0.2380 - val_accuracy: 0.9321 - val_loss: 0.2386
# Epoch 20/50
# 469/469 - 5s - 10ms/step - accuracy: 0.
50
# 469/469 - 5s - 10ms/step - accuracy: 0.9430 - loss: 0.2179 - val_accuracy: 0.9408 - val_loss: 0.2526
# Epoch 46/50
# 469/469 - 5s - 12ms/step - accuracy: 0.9431 - loss: 0.2147 - val_accuracy: 0.9437 - val_loss: 0.2360
# Epoch 47/50
# 469/469 - 10s - 20ms/step - accuracy: 0.9380 - loss: 0.2382 - val_accuracy: 0.9279 - val_loss: 0.2731
# Epoch 48/50
# 469/469 - 6s - 13ms/step - accuracy: 0.9374 - loss: 0.2329 - val_accuracy: 0.9285 - val_loss: 0.2910
# Epoch 49/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9382 - loss: 0.2407 - val_accuracy: 0.9379 - val_loss: 0.2718
# Epoch 50/50
# 469/469 - 7s - 15ms/step - accuracy: 0.9373 - loss: 0.2513 - val_accuracy: 0.9351 - val_loss: 0.2679
# 313/313 - 1s - 3ms/step - accuracy: 0.9351 - loss: 0.2679
# Adam 정확률= 93.51000189781189
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44257 (\N{HANGUL SYLLABLE GOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# 다른 옵티마이저 임포트
from tensorflow.keras.optimizers import RMSprop, Adagrad

# 로드&전처리
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
x_train = x_train.reshape(60000, 784).astype(np.float32) / 255.0
x_test  = x_test.reshape(10000, 784).astype(np.float32) / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test  = tf.keras.utils.to_categorical(y_test, 10)

#RMSprop
mlp_rms = Sequential()
mlp_rms.add(Dense(units=512, activation='sigmoid', input_shape=(784,)))
# 은닉층 활성함수 시그노이드로 변경
mlp_rms.add(Dense(units=10, activation='softmax'))

# optimizer를 RMSprop으로 변경
# learning_rate 값 수정: 높은 발산에서의 결과를 보기위해 수정
mlp_rms.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(learning_rate=0.1),
    metrics=['accuracy']
)

hist_rms = mlp_rms.fit(
    x_train, y_train,
    batch_size=32, # 배치사이즈를 줄여 더 자주 업데이트 하게 함
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=2
)

print('RMSprop 정확률=', mlp_rms.evaluate(x_test, y_test, verbose = 0) [1] * 100)

# Adagrad
mlp_ada = Sequential()
mlp_ada.add(Dense(units=512, activation='sigmoid', input_shape=(784,)))
mlp_ada.add(Dense(units=10, activation='softmax'))

# optimizer를 Adagrad로 변경
# learning_rate 값 수정: 높은 발산에서의 결과를 보기위해 수정
mlp_ada.compile(
    loss='categorical_crossentropy',
    optimizer=Adagrad(learning_rate=0.1),
    metrics=['accuracy']
)

hist_ada = mlp_ada.fit(
    x_train, y_train,
    batch_size=32, # 배치사이즈를 줄여 더 자주 업데이트 하게 함
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=2
)
print('RMSprop 정확률=', mlp_ada.evaluate(x_test, y_test, verbose = 0) [1] * 100)

#정확도 그래프
import matplotlib.pyplot as plt

plt.plot(hist_rms.history['accuracy'], 'g--')
plt.plot(hist_rms.history['val_accuracy'], 'g')
plt.plot(hist_ada.history['accuracy'], 'm--')
plt.plot(hist_ada.history['val_accuracy'], 'm')

plt.title('RMSprop vs Adagrad 정확도')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim(0.6, 1.0) # 축범위 조절
plt.legend()
plt.grid()
plt.show()

# Loss 그래프
plt.figure(figsize=(8,5))
plt.plot(hist_rms.history['loss'],linestyle='--', label='train_rms_loss')
plt.plot(hist_rms.history['val_loss'], label='val_rms_loss')
plt.plot(hist_ada.history['loss'], linestyle='--', label='train_ada_loss')
plt.plot(hist_ada.history['val_loss'], label='val_ada_loss')

plt.title('RMSprop vs Adagrad Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 1875/1875 - 14s - 7ms/step - accuracy: 0.8001 - loss: 2.2346 - val_accuracy: 0.9079 - val_loss: 1.0277
# Epoch 2/50
# 1875/1875 - 13s - 7ms/step - accuracy: 0.8843 - loss: 1.5414 - val_accuracy: 0.9005 - val_loss: 1.4627
# Epoch 3/50
# 1875/1875 - 12s - 6ms/step - accuracy: 0.8980 - loss: 1.5165 - val_accuracy: 0.9171 - val_loss: 1.4554
# Epoch 4/50
# 1875/1875 - 21s - 11ms/step - accuracy: 0.9081 - loss: 1.4501 - val_accuracy: 0.9225 - val_loss: 1.1678
# Epoch 5/50
# 1875/1875 - 21s - 11ms/step - accuracy: 0.9145 - loss: 1.4318 - val_accuracy: 0.9019 - val_loss: 1.7072
# Epoch 6/50
# 1875/1875 - 20s - 11ms/step - accuracy: 0.9193 - loss: 1.4018 - val_accuracy: 0.8852 - val_loss: 2.3343
# Epoch 7/50
# 1875/1875 - 20s - 10ms/step - accuracy: 0.9237 - loss: 1.4070 - val_accuracy: 0.9307 - val_loss: 1.3318
# Epoch 8/50
# 1875/1875 - 22s - 12ms/step - accuracy: 0.9317 - loss: 1.3039 - val_accuracy: 0.9413 - val_loss: 1.1157
# Epoch 9/50
# 1875/1875 - 12s - 6ms/step - accuracy: 0.9316 - loss: 1.3066 - val_accuracy: 0.9181 - val_loss: 1.6827
# Epoch 10/50
# 1875/1875 - 21s - 11ms/step - accuracy: 0.9323 - loss: 1.3103 - val_accuracy: 0.9380 - val_loss: 1.2885
# Epoch 11/50
# 1875/1875 - 12s - 7ms/step - accuracy: 0.9372 - loss: 1.2850 - val_accuracy: 0.9334 - val_loss: 1.3419
# Epoch 12/50
# 1875/1875 - 20s - 11ms/step - accuracy: 0.9390 - loss: 1.2591 - val_accuracy: 0.9365 - val_loss: 1.4203
# Epoch 13/50
# 1875/1875 - 13s - 7ms/step - accuracy: 0.9399 - loss: 1.2319 - val_accuracy: 0.9219 - val_loss: 1.8741
# Epoch 14/50
# 1875/1875 - 12s - 7ms/step - accuracy: 0.9429 - loss: 1.2395 - val_accuracy: 0.9385 - val_loss: 1.3804
# Epoch 15/50
# 1875/1875 - 13s - 7ms/step - accuracy: 0.9426 - loss: 1.2231 - val_accuracy: 0.9427 - val_loss: 1.3833
# Epoch 16/50
# 1875/1875 - 12s - 7ms/step - accuracy: 0.9441 - loss: 1.2045 - val_accuracy: 0.9369 - val_loss: 1.6151
# Epoch 17/50
# 1875/1875 - 21s - 11ms/step - accuracy: 0.9447 - loss: 1.2579 - val_accuracy: 0.9324 - val_loss: 1.6655
# Epoch 18/50
# 1875/1875 - 20s - 11ms/step - accuracy: 0.